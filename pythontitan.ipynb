# %% [markdown]
# <h2>Opening and Resizing an Image</h2>

# %%
from PIL import Image
pic= Image.open("sample.jpg") # open colour image

# %%
x, y = pic.size
x //= 5
y //= 5
smaller = pic.resize((x, y))
smaller
# Out:
# <PIL.Image.Image image mode=RGB size=240x159 at 0x27E9513DDF0>

# %% [markdown]
# <h3>Export as JPEG</h3>

# %%
outfile ="smaller.jpg"
try:
    smaller.save(outfile)
except IOError:
    print("cannot convert", outfile)

# %% [markdown]
# <h2>B&W Conversion</h2>

# %%
better_file = smaller.convert("L") # convert image to B&W
better_file
# Out:
# <PIL.Image.Image image mode=L size=240x159 at 0x27E9514E280>

# %%
#Auto Constrast
from PIL import ImageOps
with_constrast = ImageOps.autocontrast(better_file)
with_constrast
# Out:
# <PIL.Image.Image image mode=L size=240x159 at 0x27E963A2EE0>

# %% [markdown]
# <h2>Convert a negative to a positive</h2>

# %%
im_invert = ImageOps.invert(better_file)
im_invert
# Out:
# <PIL.Image.Image image mode=L size=240x159 at 0x27E963BA190>

# %% [markdown]
# <h3>Transposing an image</h3>
# <p>To rotate the image in 90 degree steps, you can either use the rotate() method or the transpose() method. The latter can also be used to flip an image around its horizontal or vertical axis.</p>

# %%
out = smaller.transpose(Image.FLIP_LEFT_RIGHT)
out
# Out:
# <PIL.Image.Image image mode=RGB size=240x159 at 0x27E963BA2E0>

# %%
out = smaller.transpose(Image.FLIP_TOP_BOTTOM)
out
# Out:
# <PIL.Image.Image image mode=RGB size=240x159 at 0x27E963BA4C0>

# %%
out = smaller.transpose(Image.ROTATE_90)
out
# Out:
# <PIL.Image.Image image mode=RGB size=159x240 at 0x27E9603AF10>

# %%
out = smaller.transpose(Image.ROTATE_180)
out
# Out:
# <PIL.Image.Image image mode=RGB size=240x159 at 0x27E963BA700>

# %%
out = smaller.transpose(Image.ROTATE_270)
out
# Out:
# <PIL.Image.Image image mode=RGB size=159x240 at 0x27E963BA7C0>

# %% [markdown]
# <h2>Filters - Add Details</h2>

# %%
from PIL import ImageFilter
details = smaller.filter(ImageFilter.DETAIL)


from PIL import ImageEnhance
enh = ImageEnhance.Contrast(details)
enh.enhance(1.3).show("30% more contrast")

details
# Out:
# <PIL.Image.Image image mode=RGB size=240x159 at 0x27E963BADC0>

# %% [markdown]
# <h2>Filters - Edge Detection etc...</h2>

# %%
edges = smaller.filter(ImageFilter.FIND_EDGES)
edges
# Out:
# <PIL.Image.Image image mode=RGB size=240x159 at 0x27E95121640>

# %%
bands = edges.split()
bands[0]
# Out:
# <PIL.Image.Image image mode=L size=240x159 at 0x27E960F9610>

# %% [markdown]
# <h3>Create a thumbnail</h3>

# %%
size = (128, 128)  
try:
    smaller.thumbnail(size)
    smaller.save("thumbnail.jpg", "JPEG")
except IOError:
    print("cannot create thumbnail for", outfile)
